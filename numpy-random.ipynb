# %% [markdown]
# # The numpy Random Package
#
# ***

# %%
import numpy as np

import matplotlib.pyplot as plt

# %%
# Change default style sheet. 
plt.style.use( 'ggplot')

# Change the default figure size 
plt.rcParams['figure.figsize'] = [10, 5]

# %% [markdown]
# <br>
#
# ## numpy.random.normal
#
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html
#
# ***

# %%
mu, sigma = 0, 0.1 # mean and standard deviation
s = np.random.normal(mu, sigma, 1000)

# %%
# Look at the first ten items.
s[:10]
# Out:
# array([ 0.1662488 ,  0.0070792 , -0.11113976, -0.22279055, -0.1427567 ,
#        -0.04088299,  0.16163118, -0.18963939, -0.04178405,  0.00425062])

# %%
abs(mu - np.mean(s))
# Out:
# 0.0010149485549039265

# %%
abs(sigma - np.std(s, ddof=1))
# Out:
# 0.0028360109233871167

# %%
count, bins, ignored = plt.hist(s, 30, density=True)
f = 1/(sigma * np.sqrt(2 * np.pi)) *np.exp(-(bins - mu)**2/(2*sigma**2) )
plt.plot(bins, f, linewidth=2)
plt.show()

# %% [markdown]
# ## References
#
# 1.

# %% [markdown]
# ***
#
# ## END
